# %% [markdown]
# # LIBROSA
#
# In this problem, we are going to use librosa. It is a python library which is used to preprocess the audio and speech data. The main purpose of librosa is to process the audio and convert it into features for modeling.

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
import zipfile
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.1.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (2026.2.25)

# %%
os.environ['KAGGLE_USERNAME'] = "abdulrehman1302"
os.environ['KAGGLE_KEY'] = "KGAT_03e294475347e3d3bea1fab2be412962"
print(os.environ['KAGGLE_USERNAME'])
print(os.environ['KAGGLE_KEY'])
# Out:
# abdulrehman1302
# KGAT_03e294475347e3d3bea1fab2be412962

# %%
# !kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.0), please consider upgrading to the latest version (2.0.1)
# Dataset URL: https://www.kaggle.com/datasets/ejlok1/toronto-emotional-speech-set-tess
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# Downloading toronto-emotional-speech-set-tess.zip to /content
# 100% 428M/428M [00:04<00:00, 100MB/s]

# %%
zip_ref=zipfile.ZipFile('/content/toronto-emotional-speech-set-tess.zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import os

paths = []
labels = []

DATASET_PATH = "/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/"

for dirname, _, filenames in os.walk(DATASET_PATH):
    for filename in filenames:
        if filename.endswith(".wav"):
            full_path = os.path.join(dirname, filename)
            paths.append(full_path)

            # Try filename label
            if "_" in filename:
                label = filename.split('_')[-1].split('.')[0]
            else:
                # fallback: folder name
                label = os.path.basename(dirname)

            labels.append(label.lower())

print("Dataset Loaded")
print("Total files:", len(paths))
# Out:
# Dataset Loaded
# Total files: 2800

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_pleasant_surprised/YAF_which_ps.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_pleasant_surprised/YAF_said_ps.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_pleasant_surprised/YAF_mob_ps.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_pleasant_surprised/YAF_mouse_ps.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_pleasant_surprised/YAF_bean_ps.wav']

# %%
labels[:5]
# Out:
# ['ps', 'ps', 'ps', 'ps', 'ps']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /content/tess toronto emotional speech set dat...    ps
# 1  /content/tess toronto emotional speech set dat...    ps
# 2  /content/tess toronto emotional speech set dat...    ps
# 3  /content/tess toronto emotional speech set dat...    ps
# 4  /content/tess toronto emotional speech set dat...    ps

# %%
df['label'].value_counts()
# Out:
# label
# ps         400
# happy      400
# sad        400
# fear       400
# disgust    400
# angry      400
# neutral    400
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    mfcc = mfcc.T   # (time_steps, 40)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([[-3.1439984e+02,  4.0531891e+01,  2.6318613e-01, ...,
#          8.4999409e+00, -1.2835009e+01,  3.5168095e+00],
#        [-3.0992944e+02,  1.0789125e+01, -5.0979509e+00, ...,
#          6.3646550e+00, -9.9725304e+00, -2.5412736e+00],
#        [-3.2194418e+02, -9.5677261e+00, -1.0361108e+00, ...,
#          5.9057980e+00, -1.0587493e+00, -1.3227088e+00],
#        ...,
#        [-5.2870941e+02,  6.7224109e-01, -2.4687805e+01, ...,
#          3.8782411e+00,  2.4700785e+00,  1.5710306e+00],
#        [-5.7044647e+02,  2.4069391e+01, -1.6124056e+01, ...,
#          3.0565314e+00, -1.0489758e+00,  3.7207088e+00],
#        [-6.2019202e+02,  3.2694939e+01,  4.1018338e+00, ...,
#          1.7496808e+00, -1.2435820e+00,  3.3549287e+00]], dtype=float32)

# %%
x_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
x_mfcc
# Out:
# 0       [[-314.39984, 40.53189, 0.26318613, 15.870516,...
# 1       [[-298.31384, 35.35698, -10.122568, -12.423413...
# 2       [[-373.37628, 54.674942, -8.953474, -4.0183015...
# 3       [[-315.3589, 24.122795, -2.8949692, -1.1198502...
# 4       [[-288.21487, 67.841995, -16.490545, 19.625721...
#                               ...
# 2795    [[-424.88123, 118.32527, 19.568161, 32.222336,...
# 2796    [[-430.25742, 126.82578, 19.518959, 47.3072, 4...
# 2797    [[-394.5166, 120.04816, 10.960973, 27.260014, ...
# 2798    [[-330.0855, 107.35567, 17.333868, 19.102112, ...
# 2799    [[-391.7085, 109.45819, 30.232353, 29.53062, 1...
# Name: speech, Length: 2800, dtype: object

# %%
x_mfcc[0]
# Out:
# array([[-3.1439984e+02,  4.0531891e+01,  2.6318613e-01, ...,
#          8.4999409e+00, -1.2835009e+01,  3.5168095e+00],
#        [-3.0992944e+02,  1.0789125e+01, -5.0979509e+00, ...,
#          6.3646550e+00, -9.9725304e+00, -2.5412736e+00],
#        [-3.2194418e+02, -9.5677261e+00, -1.0361108e+00, ...,
#          5.9057980e+00, -1.0587493e+00, -1.3227088e+00],
#        ...,
#        [-5.2870941e+02,  6.7224109e-01, -2.4687805e+01, ...,
#          3.8782411e+00,  2.4700785e+00,  1.5710306e+00],
#        [-5.7044647e+02,  2.4069391e+01, -1.6124056e+01, ...,
#          3.0565314e+00, -1.0489758e+00,  3.7207088e+00],
#        [-6.2019202e+02,  3.2694939e+01,  4.1018338e+00, ...,
#          1.7496808e+00, -1.2435820e+00,  3.3549287e+00]], dtype=float32)

# %%
#diffrent shapes
x_mfcc[1].shape
# Out:
# (57, 40)

# %% [markdown]
# # Padding

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
# applied padding for set the shape of array same
x_mfcc = pad_sequences(x_mfcc, padding='post', dtype='float32')

# %%
x_mfcc
# Out:
# array([[[-3.1439984e+02,  4.0531891e+01,  2.6318613e-01, ...,
#           8.4999409e+00, -1.2835009e+01,  3.5168095e+00],
#         [-3.0992944e+02,  1.0789125e+01, -5.0979509e+00, ...,
#           6.3646550e+00, -9.9725304e+00, -2.5412736e+00],
#         [-3.2194418e+02, -9.5677261e+00, -1.0361108e+00, ...,
#           5.9057980e+00, -1.0587493e+00, -1.3227088e+00],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-2.9831384e+02,  3.5356979e+01, -1.0122568e+01, ...,
#           2.2279477e+00, -6.6224113e+00,  7.9275432e+00],
#         [-3.0860309e+02,  3.3517914e+01, -1.8751354e+01, ...,
#           7.2916980e+00, -4.6124477e+00,  7.9890432e+00],
#         [-3.6962384e+02,  6.9659775e+01, -1.4735014e+01, ...,
#           8.1353645e+00,  6.5025163e+00,  5.9870081e+00],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-3.7337628e+02,  5.4674942e+01, -8.9534740e+00, ...,
#           6.3703117e+00,  1.6999502e+00,  3.5892091e+00],
#         [-3.5917233e+02,  4.8400696e+01, -8.8115196e+00, ...,
#           6.9163885e+00,  1.9887464e+00,  5.8942146e+00],
#         [-3.3589420e+02,  3.5617462e+01, -1.9165417e+01, ...,
#          -8.3701611e-01, -5.5709009e+00,  6.0722547e+00],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        ...,
#
#        [[-3.9451660e+02,  1.2004816e+02,  1.0960973e+01, ...,
#           1.3661465e+01, -6.3455552e-01, -3.2244182e+00],
#         [-4.0214258e+02,  9.5837234e+01,  1.1990681e+01, ...,
#           2.1014593e+01, -3.1105065e-01, -5.4006534e+00],
#         [-4.6269022e+02,  3.3637405e+01,  1.9561388e+00, ...,
#           3.3193813e+01, -2.7408276e+00, -1.4837648e+01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-3.3008551e+02,  1.0735567e+02,  1.7333868e+01, ...,
#           1.4374245e+01,  4.1251335e+00,  7.0742750e+00],
#         [-3.6733151e+02,  9.4079597e+01,  2.7493509e+01, ...,
#           2.1992296e+01,  7.1132221e+00,  1.5929360e+01],
#         [-4.8309344e+02,  4.8029499e+01,  3.3060524e+01, ...,
#           4.8433208e+01,  1.2146874e+01,  1.1578257e+01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-3.9170850e+02,  1.0945819e+02,  3.0232353e+01, ...,
#           1.7278053e+01,  6.9254298e+00, -1.3119848e+00],
#         [-3.9965213e+02,  8.5057587e+01,  2.9052778e+01, ...,
#           2.6017342e+01,  7.5010791e+00, -3.9924076e+00],
#         [-4.5841010e+02,  3.1569790e+01,  1.8748653e+01, ...,
#           5.0458660e+01,  1.5331257e+01, -5.6343241e+00],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32)

# %%
x_mfcc.shape
# Out:
# (2800, 108, 40)

# %%
# first converted from pandas series to python list and then numpy array
x = [x for x in x_mfcc]
x = np.array(x)
x.shape
# Out:
# (2800, 108, 40)

# %%
## input split
x= np.expand_dims(x, -1)
x.shape
# Out:
# (2800, 108, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# # Create RNN Model

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
model = Sequential([

    # RNN layer
    SimpleRNN(64, return_sequences=True, input_shape=(x.shape[1], x.shape[2])),
    BatchNormalization(),
    Dropout(0.4),

    # RNN layer
    SimpleRNN(32),
    BatchNormalization(),
    Dropout(0.4),

    Dense(16, activation='relu'),
    Dropout(0.3),

    # Output layer
    Dense(7, activation='softmax')
])

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_8 (SimpleRNN)        │ (None, 108, 64)        │         6,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 108, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 108, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,855 (42.40 KB)
#  Trainable params: 10,663 (41.65 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
history = model.fit(
    x, y,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    # callbacks=[early_stop, lr_reduce]
)
# Out:
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.1777 - loss: 2.2926 - val_accuracy: 0.0036 - val_loss: 2.3645
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.2188 - loss: 2.0161 - val_accuracy: 0.0000e+00 - val_loss: 2.6771
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.2473 - loss: 1.9277 - val_accuracy: 0.2107 - val_loss: 2.2983
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.2821 - loss: 1.7709 - val_accuracy: 0.1071 - val_loss: 2.5767
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.3174 - loss: 1.6958 - val_accuracy: 0.1054 - val_loss: 2.6449
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3451 - loss: 1.6288 - val_accuracy: 0.0036 - val_loss: 2.7032
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.2897 - loss: 1.7251 - val_accuracy: 0.0000e+00 - val_loss: 4.0556
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.1714 - loss: 1.9952 - val_accuracy: 0.0000e+00 - val_loss: 3.1013
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.1701 - loss: 1.9270 - val_accuracy: 0.0000e+00 - val_loss: 2.9037
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.1790 - loss: 1.8792 - val_accuracy: 0.0000e+00 - val_loss: 2.8372
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.1781 - loss: 1.8854 - val_accuracy: 0.0000e+00 - val_loss: 2.9231
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.1750 - loss: 1.8677 - val_accuracy: 0.0000e+00 - val_loss: 2.7982
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1723 - loss: 1.8635 - val_accuracy: 0.0000e+00 - val_loss: 2.9785
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.1888 - loss: 1.8555 - val_accuracy: 0.0000e+00 - val_loss: 2.9152
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.1763 - loss: 1.8531 - val_accuracy: 0.0000e+00 - val_loss: 2.7630
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1643 - loss: 1.8514 - val_accuracy: 0.0000e+00 - val_loss: 2.9953
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.1964 - loss: 1.8548 - val_accuracy: 0.0000e+00 - val_loss: 2.7751
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.1848 - loss: 1.8489 - val_accuracy: 0.0000e+00 - val_loss: 2.7353
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1821 - loss: 1.8380 - val_accuracy: 0.0000e+00 - val_loss: 2.7760
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1835 - loss: 1.8381 - val_accuracy: 0.0000e+00 - val_loss: 3.1455
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.1821 - loss: 1.8419 - val_accuracy: 0.0000e+00 - val_loss: 3.1050
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1826 - loss: 1.8384 - val_accuracy: 0.0000e+00 - val_loss: 3.1205
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1897 - loss: 1.8382 - val_accuracy: 0.0000e+00 - val_loss: 2.9964
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.1750 - loss: 1.8428 - val_accuracy: 0.0000e+00 - val_loss: 3.1052
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1746 - loss: 1.8368 - val_accuracy: 0.0000e+00 - val_loss: 3.1298
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1781 - loss: 1.8316 - val_accuracy: 0.0000e+00 - val_loss: 3.0415
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1804 - loss: 1.8361 - val_accuracy: 0.0000e+00 - val_loss: 3.0972
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.1821 - loss: 1.8388 - val_accuracy: 0.0000e+00 - val_loss: 3.0628
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.1772 - loss: 1.8321 - val_accuracy: 0.0000e+00 - val_loss: 3.1073
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1643 - loss: 1.8354 - val_accuracy: 0.0000e+00 - val_loss: 3.0684
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.1790 - loss: 1.8311 - val_accuracy: 0.0000e+00 - val_loss: 3.0682
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.1879 - loss: 1.8302 - val_accuracy: 0.0000e+00 - val_loss: 3.1076
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1933 - loss: 1.8302 - val_accuracy: 0.0000e+00 - val_loss: 3.1298
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1839 - loss: 1.8279 - val_accuracy: 0.0000e+00 - val_loss: 3.1768
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.1795 - loss: 1.8287 - val_accuracy: 0.0000e+00 - val_loss: 3.1465
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.1728 - loss: 1.8306 - val_accuracy: 0.0000e+00 - val_loss: 3.0802
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1821 - loss: 1.8282 - val_accuracy: 0.0000e+00 - val_loss: 3.2122
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1888 - loss: 1.8258 - val_accuracy: 0.0000e+00 - val_loss: 3.2224
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.2094 - loss: 1.8095 - val_accuracy: 0.0000e+00 - val_loss: 2.9941
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.1853 - loss: 1.8193 - val_accuracy: 0.0000e+00 - val_loss: 3.1379
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1754 - loss: 1.8322 - val_accuracy: 0.0000e+00 - val_loss: 3.1501
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.1888 - loss: 1.8278 - val_accuracy: 0.0000e+00 - val_loss: 3.0926
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.1790 - loss: 1.8400 - val_accuracy: 0.0000e+00 - val_loss: 3.3691
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1893 - loss: 1.8389 - val_accuracy: 0.0000e+00 - val_loss: 3.2390
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1866 - loss: 1.8371 - val_accuracy: 0.0000e+00 - val_loss: 3.1887
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.1786 - loss: 1.8358 - val_accuracy: 0.0000e+00 - val_loss: 3.0628
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.1866 - loss: 1.8260 - val_accuracy: 0.0000e+00 - val_loss: 3.1692
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1808 - loss: 1.8308 - val_accuracy: 0.0000e+00 - val_loss: 4.3464
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.1853 - loss: 1.8241 - val_accuracy: 0.0000e+00 - val_loss: 3.8377
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.1728 - loss: 1.8254 - val_accuracy: 0.0000e+00 - val_loss: 3.5127

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(64, return_sequences=False, input_shape=(x.shape[1], x.shape[2])),
    Dropout(0.3),

    # Dense(32, activation='relu'),
    # Dropout(0.3),

    Dense(16, activation='relu'),
    Dropout(0.3),

    Dense(7, activation='softmax')
])

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_14 (LSTM)                  │ (None, 64)             │        26,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,039 (109.53 KB)
#  Trainable params: 28,039 (109.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(x, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.2576 - loss: 1.7877 - val_accuracy: 0.0000e+00 - val_loss: 2.2583
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.3973 - loss: 1.4788 - val_accuracy: 0.0000e+00 - val_loss: 2.9938
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.5031 - loss: 1.1652 - val_accuracy: 0.0000e+00 - val_loss: 3.2462
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5862 - loss: 0.9630 - val_accuracy: 0.0000e+00 - val_loss: 3.3752
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6219 - loss: 0.8376 - val_accuracy: 0.0000e+00 - val_loss: 4.1425
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.6696 - loss: 0.7335 - val_accuracy: 0.0018 - val_loss: 4.3167
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.7196 - loss: 0.6117 - val_accuracy: 0.0018 - val_loss: 4.3932
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.7411 - loss: 0.5713 - val_accuracy: 0.0018 - val_loss: 4.7543
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.7107 - loss: 0.6360 - val_accuracy: 0.0161 - val_loss: 3.9829
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.7701 - loss: 0.5027 - val_accuracy: 0.0018 - val_loss: 4.6937
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.8196 - loss: 0.4468 - val_accuracy: 0.0196 - val_loss: 3.7861
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8554 - loss: 0.3533 - val_accuracy: 0.2196 - val_loss: 3.0188
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8719 - loss: 0.3149 - val_accuracy: 0.3768 - val_loss: 3.4522
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8897 - loss: 0.2935 - val_accuracy: 0.4768 - val_loss: 3.1691
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8317 - loss: 0.4093 - val_accuracy: 0.4768 - val_loss: 3.3137
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.8982 - loss: 0.2878 - val_accuracy: 0.4696 - val_loss: 3.1681
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9147 - loss: 0.2383 - val_accuracy: 0.4411 - val_loss: 3.1452
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9201 - loss: 0.2428 - val_accuracy: 0.4554 - val_loss: 3.0866
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9299 - loss: 0.2093 - val_accuracy: 0.5196 - val_loss: 2.7117
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9451 - loss: 0.1783 - val_accuracy: 0.4786 - val_loss: 3.4096
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9446 - loss: 0.1876 - val_accuracy: 0.4982 - val_loss: 3.1347
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8996 - loss: 0.3460 - val_accuracy: 0.5054 - val_loss: 4.0056
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9103 - loss: 0.2565 - val_accuracy: 0.4196 - val_loss: 3.6855
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8473 - loss: 0.3840 - val_accuracy: 0.5625 - val_loss: 3.2586
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.8326 - loss: 0.3771 - val_accuracy: 0.4857 - val_loss: 3.5870
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8567 - loss: 0.3241 - val_accuracy: 0.4964 - val_loss: 3.3642
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8772 - loss: 0.2816 - val_accuracy: 0.4357 - val_loss: 3.8461
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.8853 - loss: 0.2796 - val_accuracy: 0.4625 - val_loss: 3.7239
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9183 - loss: 0.2048 - val_accuracy: 0.5107 - val_loss: 3.3446
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9531 - loss: 0.1716 - val_accuracy: 0.4232 - val_loss: 4.1376
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9540 - loss: 0.1511 - val_accuracy: 0.4161 - val_loss: 4.3454
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9580 - loss: 0.1554 - val_accuracy: 0.3929 - val_loss: 4.2651
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9661 - loss: 0.1102 - val_accuracy: 0.4429 - val_loss: 4.3386
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9754 - loss: 0.0882 - val_accuracy: 0.4196 - val_loss: 4.9871
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9701 - loss: 0.1048 - val_accuracy: 0.4179 - val_loss: 5.1835
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9781 - loss: 0.0731 - val_accuracy: 0.4732 - val_loss: 4.9962
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9741 - loss: 0.0837 - val_accuracy: 0.5107 - val_loss: 4.6221
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9652 - loss: 0.1142 - val_accuracy: 0.3875 - val_loss: 4.9938
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9728 - loss: 0.0883 - val_accuracy: 0.5696 - val_loss: 2.6040
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9563 - loss: 0.1473 - val_accuracy: 0.3411 - val_loss: 5.2906
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9567 - loss: 0.1435 - val_accuracy: 0.5964 - val_loss: 2.7023
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9750 - loss: 0.0869 - val_accuracy: 0.5214 - val_loss: 3.5420
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9741 - loss: 0.0744 - val_accuracy: 0.6036 - val_loss: 2.5401
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9795 - loss: 0.0757 - val_accuracy: 0.6339 - val_loss: 2.4778
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9714 - loss: 0.0793 - val_accuracy: 0.5446 - val_loss: 3.1560
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9705 - loss: 0.0834 - val_accuracy: 0.4589 - val_loss: 3.6966
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9705 - loss: 0.0838 - val_accuracy: 0.5446 - val_loss: 3.0845
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9790 - loss: 0.0594 - val_accuracy: 0.5571 - val_loss: 3.7438
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9705 - loss: 0.0931 - val_accuracy: 0.4464 - val_loss: 3.8985
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9688 - loss: 0.1150 - val_accuracy: 0.2821 - val_loss: 7.2785

# %%
# best val accuracy: 72.32
# use checkpoint to save the best val accuracy model
# adjust learning rate for slow convergence

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
