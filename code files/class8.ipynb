# %% [markdown]
# # File Handling:
#
# The code referes to access the files, edit, delete, update, modify as your own way.
#
# Operations on Files:
#
# * open
# * read
# * write
# * close

# %% [markdown]
# # Different modes of Operations
# 1. 'r': open for reading (default)
# 2. 'w': open for reading, truncation the file first (overwrite)
# 3. 'x': create a new file and open it for writing
# 4. 'a': open for writing, appanding to the end of the file if it exists
# 5. 'b': binary mode
# 6. 't': text mode (default)
# 7. '+': open a disk file for updating
#
# # Difference Between Modes:
#
# The argument mode points to a string beginning with one of the following
#  sequences (Additional characters may follow these sequences.):
#
# 1. "r"   Open text file for reading.  The stream is positioned at the
#          beginning of the file.
#
# 2.  "r+"  Open for reading and writing.  The stream is positioned at the
#          beginning of the file.
#
# 3.  "w"   Truncate file to zero length or create text file for writing.
#          The stream is positioned at the beginning of the file.
#
# 4. "w+"  Open for reading and writing.  The file is created if it does not
#          exist, otherwise it is truncated.  The stream is positioned at
#          the beginning of the file.
#
# 5. "a"   Open for writing.  The file is created if it does not exist.  The
#          stream is positioned at the end of the file.  Subsequent writes
#          to the file will always end up at the then current end of file,
#          irrespective of any intervening fseek(3) or similar.
#
# 6. "a+"  Open for reading and writing.  The file is created if it does not
#          exist.  The stream is positioned at the end of the file.  Subse-
#          quent writes to the file will always end up at the then current
#          end of file, irrespective of any intervening fseek(3) or similar.

# %% [markdown]
# ## 1. Reading

# %%
# open & read File
f=open("sample.txt","r")  #read mode
data=f.read()
print(data)
print(type(data))
# Out:
# I am Abdul Rehmanython tomorrow. Than i go to Machine learning I will become an Ai Engineer I will become an Ai Engineer
# <class 'str'>

# %%
# open & read File
f=open("sample.txt","r")  #read mode
data=f.read(5) #read particular characters
print(data)
# Out:
# I am

# %%
# open & read File
f=open("sample.txt","r")  #read mode

# readline ---> red the document line by line (one line at a time)
line_1=f.readline() #read first line
line_2=f.readline() #read second line
print(line_1)
print(line_2)
# Out:
# I am Abdul Rehmanython tomorrow. Than i go to Machine learning I will become an Ai Engineer I will become an Ai Engineer

# %% [markdown]
# ### 2. Writing

# %%
# open & writing to File ----> override the existing data on previous
f=open("sample.txt","w")  #write mode with override
f.write("I want to learn python tomorrow.")
# Out:
# 32

# %%
#appand to File ----> append the new data in existing without override
f=open("sample.txt","a")  #write mode without override
f.write(" Than i go to Machine learning")
# Out:
# 30

# %% [markdown]
# ### 3. Reading & Writing Simultanuously

# %%
# override to the file in start
f=open('sample.txt','r+') #override text in start
f.write("I am Abdul Rehman") #read the text from onwards to override text
print(f.read())
f.close()
# Out:
# ython tomorrow. Than i go to Machine learning

# %%
# override to the file in start
f=open('sample.txt','r+') #override text in start
#f.write("I am Abdul Rehman") #read the text from onwards to override text
print(f.read())
f.write(" I will become an Ai Engineer")
f.close()
# Out:
# I am Abdul Rehmanython tomorrow. Than i go to Machine learning

# %%
# a+ ----> stream is positioned at the end of the file
f=open('sample.txt','a+') #pace the end of the pointer for reading
#f.write("I am Abdul Rehman") #read the text from onwards to override text
print(f.read())
f.write(" ABC 123")
f.close()

# %% [markdown]
# ### With Open Syntax

# %%
with open('sample.txt','r') as f:
  data=f.read()
  print(data)
# Out:
# I am Abdul Rehmanython tomorrow. Than i go to Machine learning I will become an Ai Engineer I will become an Ai Engineer ABC 123

# %%
with open('sample.txt','w') as f:
  f.write('new data with write')

# %% [markdown]
# ### Deletig a File
#
# #### Module:
# Module is code library that is written by another programer that generally has a function we can use.

# %%
#module ---> we are using to delete a file
import os

os.remove('sample.txt')

# %% [markdown]
# ## Practise Questions

# %% [markdown]
# ###Q1:
# create a file 'practise.txt' using python. Add the following data in it:
#
# " Hi Everyone
#
# We are learning file I/O
#
# Using Python
#
# I like programming in python "

# %%
with open('practise.txt','w') as f:
  f.write("Hi Everyone\nWe are learning file I/O\n")
  f.write("Using Python.\nI like programming in python")

# %% [markdown]
# ###Q2:
# write a function that replace all occurances of "java" with "python" in above file.

# %%
with open('practise.txt','r') as f:
  data=f.read()
  data=data.replace('java','python') #using replace method of python
with open('practise.txt','w') as f:
  f.write(data)

# %% [markdown]
# ###Q3:
# Search if the word "learning" exists in the file or not.

# %%
with open('practise.txt','r') as f:
  data=f.read()
  if 'learning' in data:
    print('Yes')
  else:
    print('No')
# Out:
# Yes

# %% [markdown]
# # Exception Handling
#
# Referes to the error handling in the program according to your own way.
#
# There are two stages of error in a program:
#
# 1. During Compilation (Cnvert the code in to machine language) : Syntax Error
# 2. During Execution (Running the machine code ) : Exceptions

# %% [markdown]
# ###1. Syntax Error
#
# - Something in the program is not written according to the program grammar.
# - Error is raised by the interpreter/compiler
# - You can solve it by rectifying the program

# %%
# Examples of syntax error
print 'hello world'
# Out:
#   File "/tmp/ipython-input-528539990.py", line 2
#     print 'hello world'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# ### Other examples of syntax error
#
# - Leaving symbols like colon,brackets
# - Misspelling a keyword
# - Incorrect indentation
# - empty if/else/loops/class/functions

# %%
a = 5
if a==3
  print('hello')
# Out:
#   File "/tmp/ipython-input-3315782095.py", line 2
#     if a==3
#            ^
# SyntaxError: expected ':'

# %%
a = 5
iff a==3:
  print('hello')
# Out:
#   File "/tmp/ipython-input-521424995.py", line 2
#     iff a==3:
#         ^
# SyntaxError: invalid syntax

# %%
a = 5
if a==3:
print('hello')
# Out:
#   File "/tmp/ipython-input-3610895221.py", line 3
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
L = [1,2,3]
L[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1169124241.py in <cell line: 0>()
#       2 # The IndexError is thrown when trying to access an item at an invalid index.
#       3 L = [1,2,3]
# ----> 4 L[100]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5.3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1819532709.py in <cell line: 0>()
#       1 # ModuleNotFoundError
#       2 # The ModuleNotFoundError is thrown when a module could not be found.
# ----> 3 import mathi
#       4 math.floor(5.3)
#
# ModuleNotFoundError: No module named 'mathi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# KeyError
# The KeyError is thrown when a key is not found

d = {'name':'nitish'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2582424432.py in <cell line: 0>()
#       3
#       4 d = {'name':'nitish'}
# ----> 5 d['age']
#
# KeyError: 'age'

# %%
# TypeError
# The TypeError is thrown when an operation or function is applied to an object of an inappropriate type.
1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3512945353.py in <cell line: 0>()
#       1 # TypeError
#       2 # The TypeError is thrown when an operation or function is applied to an object of an inappropriate type.
# ----> 3 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ValueError
# The ValueError is thrown when a function's argument is of an inappropriate type.
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1016288878.py in <cell line: 0>()
#       1 # ValueError
#       2 # The ValueError is thrown when a function's argument is of an inappropriate type.
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# NameError
# The NameError is thrown when an object could not be found.
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3129957860.py in <cell line: 0>()
#       1 # NameError
#       2 # The NameError is thrown when an object could not be found.
# ----> 3 print(k)
#
# NameError: name 'k' is not defined

# %%
# AttributeError
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-246304454.py in <cell line: 0>()
#       1 # AttributeError
#       2 L = [1,2,3]
# ----> 3 L.upper()
#       4
#       5 # Stacktrace
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ###2. Exceptions
#
# If things go wrong during the execution of the program(runtime). It generally happens when something unforeseen has happened.
#
# - It is actually a logical error depending upon the execution of the program
# - Exceptions are raised by python runtime
# - You have to takle with your own dynamic logic
#
# #### **Examples**
#
# - Memory overflow
# - Divide by 0 -> logical error
# - Database error
#
# #### Advantages:
#
# 1. Prevents program crashes – Instead of stopping execution when an error occurs, the program can continue running.
#
# 2. Provides controlled error handling – You can decide what should happen when an error occurs.
#
# 3. Gives user-friendly messages – Instead of showing technical error traces, you can show simple and understandable messages.
#
# 4. Handles specific errors separately – Different types of errors (like ValueError, ZeroDivisionError, etc.) can be handled in different ways.

# %%
# let's create a file
with open('sample.txt','w') as f:
  f.write('hello world')

# %%
# try catch demo -----> check the code, if error occured than it goes to except that print programmer message
try:
  with open('sample1.txt','r') as f:
    print(f.read())
except:
  print('sorry file not found')
# Out:
# sorry file not found

# %%
# check the error type
try:
  f=open('sample.txt','r')
  print(f.read())
  print(m)
except Exception as e:
  print(e)
  print(e.with_traceback)
# Out:
# My name is Abdullah, I am 20 years old.
# name 'm' is not defined
# <built-in method with_traceback of NameError object at 0x7d49ce6a7d00>

# %%
# catching specific exception ---> for multiple errors
try:
  m=5
  f = open('sample1.txt','r')
  print(f.read())
  print(m)
  print(5/2)
  L = [1,2,3]
  L[100]
except FileNotFoundError:
  print('file not found')
except NameError:
  print('variable not defined')
except ZeroDivisionError:
  print("can't divide by 0")
except Exception as e:
  print(e)
# Out:
# file not found

# %%
# else ---> the work you have to do after success of try, you add that in the else
try:
  f = open('sample.txt','r')
except FileNotFoundError:
  print('File Not Found')
except Exception:
  print('Some error occured')
else:
  print(f.read())
# Out:
# My name is Abdullah, I am 20 years old.

# %%
# finally ----> no matter what, finally will execute every time
# else
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('File not found')
except Exception:
  print('Something went wrong')
else:
  print(f.read())
finally:
  print('This will Execute every time')
# Out:
# File not found
# This will Execute every time

# %% [markdown]
# ### raise Keyword:
#
# raise Keyword is used to raise exceptions or errors. The raise keyword raises an error and stops the control flow of the program. It is used to bring up the current exception in an exception handler so that it can be handled further up the call stack. We can also manually raise exceptions using the raise keyword. We can optionally pass values to the exception to clarify why that exception was raised
#
#
# ### Difference Between Try-Except & Raise:
#
# * **try-except** blocks are used to catch and handle exceptions that may be raised by other parts of the code (either built-in Python functions or custom code). They provide a mechanism to gracefully recover from errors, log information, or present user-friendly messages instead of allowing the program to crash.
#
# * **raise statements** are used to explicitly generate and propagate exceptions.

# %%
raise ZeroDivisionError("Can't divide by 0")
# Java
# try -> try
# except -> catch
# raise -> throw
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-413813504.py in <cell line: 0>()
# ----> 1 raise ZeroDivisionError("Can't divide by 0")
#       2 # Java
#       3 # try -> try
#       4 # except -> catch
#       5 # raise -> throw
#
# ZeroDivisionError: Can't divide by 0

# %%
# Example
class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exception('amount cannot be -ve')
    if self.balance < amount:
      raise Exception('Amount exceeded to balance')
    self.balance = self.balance - amount

obj = Bank(1000)
try:
  obj.withdraw(100)
except Exception as e:
  print(e)
else:
  print(obj.balance)
# Out:
# 900

# %% [markdown]
# # Modules
#
# A file containing a set of function that you want to add in your application. Consider a module as as same as as a code library.
#
# Exaple of python mdules:
#
#
# *   Math
# *   Random
# *   Time

# %%
# math module ---> use for mathematical operations
import math

# %%
print(math.pi)
print(math.e)
print(math.factorial(5))
print(math.sqrt(4))
print(math.sqrt(4))
# Out:
# 3.141592653589793
# 2.718281828459045
# 120
# 2.0
# 2.0

# %%
# Rando ----> use for random mathematical numbers
import random

# %%
print(random.randint(1,100))

a=[1,2,3,4,5,6]
random.shuffle(a)
print(a)
# Out:
# 94
# [3, 1, 6, 4, 2, 5]

# %%
# time ----> use for time stamp calculations
import time

# %%
time.time() #calculating seconds from 1st jan 1970)
# Out:
# 1758977549.5599916

# %%
print(time.ctime()) # current time
# Out:
# Sat Sep 27 12:52:31 2025

# %%
print("Hello")
time.sleep(30) # 30sec delay to run next line
print("World")
# Out:
# Hello
# World
