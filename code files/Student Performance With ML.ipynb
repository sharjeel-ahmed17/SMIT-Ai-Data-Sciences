# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set up style for plots
sns.set(style="whitegrid")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_8088\1632440041.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "c:\ProgramData\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_8088\1632440041.py", line 1, in <module>
#     import pandas as pd
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "c:\ProgramData\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "c:\ProgramData\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %% [markdown]
# # Load The Dataset

# %%
df=pd.read_csv("student_performance_data.csv")
df.head(10)
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
# 5              85                         81                25
# 6              83                         77                22
# 7              85                         84                13
# 8              62                         65                15
# 9              88                         90                 9
#
#    Practical Score (25%)  Exam Score (50%) Performance  Age  Gender  \
# 0                     17                33           B   21  Female
# 1                     14                26           C   25    Male
# 2                     11                35           B   19    Male
# 3                      9                19           D   24    Male
# 4                     17                19           D   21  Female
# 5                     17                38           A   18  Female
# 6                     23                14           C   25  Female
# 7                     14                35           B   18  Female
# 8                     16                16           D   22  Female
# 9                     21                23           C   19    Male
#
#   Marital Status  Children (if Married)   Mother Education   Father Education  \
# 0        Engaged                      0            College  Bachelor's Degree
# 1        Married                      0            College          Doctorate
# 2        Engaged                      0        High School          Doctorate
# 3         Single                      0        High School          Doctorate
# 4         Single                      0            College            College
# 5        Married                      2    Master's Degree          Doctorate
# 6        Married                      2  Bachelor's Degree  Bachelor's Degree
# 7        Engaged                      0  Bachelor's Degree        High School
# 8        Married                      1          Doctorate        High School
# 9        Married                      2        High School  Bachelor's Degree
#
#   Guardian (Sponsor) Extracurricular Activities  Online Time (Daily)  \
# 0              Uncle                         No                    3
# 1             Father                         No                    9
# 2             Mother                        Yes                    5
# 3            Brother                         No                    3
# 4             Sister                         No                    9
# 5            Brother                         No                    0
# 6             Mother                         No                    3
# 7             Father                         No                    2
# 8            Brother                        Yes                    8
# 9             Sister                         No                    9
#
#   Family Relationship Free Time Activities Alcoholic Consumption  \
# 0             Average          Watching TV                  High
# 1             Average          Socializing                   Low
# 2                Poor          Socializing                  High
# 3                Good               Sports              Moderate
# 4             Average               Sports                   Low
# 5                Good               Sports                  High
# 6                Good               Sports              Moderate
# 7                Poor          Watching TV                  High
# 8                Good               Sports                   Low
# 9             Average          Socializing              Moderate
#
#    Religious Programs (Weekly) Computer/Laptop Access (for Practicals)
# 0                            0                                     Yes
# 1                            5                                     Yes
# 2                            0                                     Yes
# 3                            4                                     Yes
# 4                            1                                      No
# 5                            7                                      No
# 6                            4                                      No
# 7                            0                                     Yes
# 8                            4                                      No
# 9                            2                                      No

# %% [markdown]
# # Data Preprocessing

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Attendance (%)                           5000 non-null   int64
#  1   Assignment Completion (%)                5000 non-null   int64
#  2   Test Score (25%)                         5000 non-null   int64
#  3   Practical Score (25%)                    5000 non-null   int64
#  4   Exam Score (50%)                         5000 non-null   int64
#  5   Performance                              5000 non-null   object
#  6   Age                                      5000 non-null   int64
#  7   Gender                                   5000 non-null   object
#  8   Marital Status                           5000 non-null   object
#  9   Children (if Married)                    5000 non-null   int64
#  10  Mother Education                         5000 non-null   object
#  11  Father Education                         5000 non-null   object
#  12  Guardian (Sponsor)                       5000 non-null   object
#  13  Extracurricular Activities               5000 non-null   object
#  14  Online Time (Daily)                      5000 non-null   int64
#  15  Family Relationship                      5000 non-null   object
#  16  Free Time Activities                     5000 non-null   object
#  17  Alcoholic Consumption                    5000 non-null   object
#  18  Religious Programs (Weekly)              5000 non-null   int64
#  19  Computer/Laptop Access (for Practicals)  5000 non-null   object
# dtypes: int64(9), object(11)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#        Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# count     5000.000000                5000.000000       5000.000000
# mean        82.863800                  82.752800         16.448200
# std         10.806341                  10.762735          5.199108
# min         21.000000                  10.000000          8.000000
# 25%         76.000000                  76.000000         12.000000
# 50%         84.000000                  84.000000         17.000000
# 75%         92.000000                  91.000000         21.000000
# max         99.000000                  99.000000         25.000000
#
#        Practical Score (25%)  Exam Score (50%)          Age  \
# count            5000.000000       5000.000000  5000.000000
# mean               16.369200         29.346000    21.476400
# std                 5.186316         12.315414     2.282649
# min                 8.000000          8.000000    18.000000
# 25%                12.000000         19.000000    19.000000
# 50%                16.000000         30.000000    21.000000
# 75%                21.000000         40.000000    23.000000
# max                25.000000         50.000000    25.000000
#
#        Children (if Married)  Online Time (Daily)  Religious Programs (Weekly)
# count            5000.000000           5000.00000                  5000.000000
# mean                0.815200              4.50760                     3.540600
# std                 1.513508              2.86419                     2.281533
# min                 0.000000              0.00000                     0.000000
# 25%                 0.000000              2.00000                     2.000000
# 50%                 0.000000              4.00000                     4.000000
# 75%                 1.000000              7.00000                     6.000000
# max                 5.000000              9.00000                     7.000000

# %%
df.isnull().sum()
# Out:
# Attendance (%)                             0
# Assignment Completion (%)                  0
# Test Score (25%)                           0
# Practical Score (25%)                      0
# Exam Score (50%)                           0
# Performance                                0
# Age                                        0
# Gender                                     0
# Marital Status                             0
# Children (if Married)                      0
# Mother Education                           0
# Father Education                           0
# Guardian (Sponsor)                         0
# Extracurricular Activities                 0
# Online Time (Daily)                        0
# Family Relationship                        0
# Free Time Activities                       0
# Alcoholic Consumption                      0
# Religious Programs (Weekly)                0
# Computer/Laptop Access (for Practicals)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)',
#        'Practical Score (25%)', 'Exam Score (50%)', 'Performance', 'Age',
#        'Gender', 'Marital Status', 'Children (if Married)', 'Mother Education',
#        'Father Education', 'Guardian (Sponsor)', 'Extracurricular Activities',
#        'Online Time (Daily)', 'Family Relationship', 'Free Time Activities',
#        'Alcoholic Consumption', 'Religious Programs (Weekly)',
#        'Computer/Laptop Access (for Practicals)'],
#       dtype='object')

# %% [markdown]
# ## Remove Un-Necessary Columns

# %%
df.drop(columns=['Age','Gender','Marital Status','Children (if Married)','Guardian (Sponsor)','Computer/Laptop Access (for Practicals)','Alcoholic Consumption','Extracurricular Activities','Mother Education','Father Education','Free Time Activities','Family Relationship','Online Time (Daily)','Religious Programs (Weekly)'],inplace=True)

# %%
df.head()
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
#
#    Practical Score (25%)  Exam Score (50%) Performance
# 0                     17                33           B
# 1                     14                26           C
# 2                     11                35           B
# 3                      9                19           D
# 4                     17                19           D

# %% [markdown]
# # Checking Uniquenes of the Columns

# %%
df['Attendance (%)'].unique()
# Out:
# array([95, 78, 97, 74, 62, 85, 83, 88, 63, 77, 92, 67, 75, 94, 96, 86, 81,
#        91, 82, 90, 79, 89, 64, 61, 84, 76, 66, 68, 98, 72, 87, 93, 71, 70,
#        80, 65, 73, 23, 22, 99, 60, 69, 32, 30, 28, 34, 33, 25, 24, 21, 27])

# %%
df['Assignment Completion (%)'].unique()
# Out:
# array([86, 92, 87, 69, 74, 81, 77, 84, 65, 90, 83, 91, 82, 97, 80, 94, 76,
#        98, 85, 78, 63, 67, 79, 93, 62, 96, 89, 71, 75, 88, 95, 70, 66, 99,
#        27, 38, 73, 72, 60, 68, 61, 64, 26, 10, 20, 18, 31, 30, 29, 35, 24,
#        22, 15, 37])

# %%
df['Test Score (25%)'].unique()
# Out:
# array([12, 19, 23, 10, 25, 22, 13, 15,  9, 18, 14, 11,  8, 20, 24, 17, 16,
#        21])

# %%
df['Practical Score (25%)'].unique()
# Out:
# array([17, 14, 11,  9, 23, 16, 21, 10, 22,  8, 13, 25, 15, 19, 12, 24, 18,
#        20])

# %%
df['Exam Score (50%)'].unique()
# Out:
# array([33, 26, 35, 19, 38, 14, 16, 23, 18, 12, 46, 34, 32, 22, 43, 39, 49,
#        29, 20, 24, 36, 37,  8, 42, 21, 17, 30, 31, 48, 44, 25, 50, 40, 13,
#        27, 41,  9, 10, 28, 45, 15, 11, 47])

# %%
df['Performance'].unique()
# Out:
# array(['B', 'C', 'D', 'A', 'E', 'F'], dtype=object)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# 1. Distribution of Attendance (%)
plt.figure(figsize=(8, 5))
sns.histplot(df['Attendance (%)'], bins=10, kde=True)
plt.title("Distribution of Attendance (%)")
plt.xlabel("Attendance (%)")
plt.ylabel("Frequency")
plt.show()

# %%
# 2. Distribution of Assignment Completion (%)
plt.figure(figsize=(8, 5))
sns.histplot(df['Assignment Completion (%)'], bins=10, kde=True)
plt.title("Distribution of Assignment Completion (%)")
plt.xlabel("Assignment Completion (%)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.title("Pyplot For Performance")
plt.pie(df['Performance'].value_counts(),labels=['B', 'C', 'D', 'A', 'E', 'F'],autopct='%0.2f')
plt.show()

# %%
# 4. Practical Score vs. Exam Score (by Performance)
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Practical Score (25%)', y='Exam Score (50%)', hue='Performance', s=100)
plt.title("Practical Score vs Exam Score (by Performance)")
plt.xlabel("Practical Score (25%)")
plt.ylabel("Exam Score (50%)")
plt.legend(title="Performance")
plt.show()

# %%
# 5. Exam Score (50%) by Performance Grade
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Performance', y='Exam Score (50%)')
plt.title("Exam Score (50%) by Performance Grade")
plt.xlabel("Performance Grade")
plt.ylabel("Exam Score (50%)")
plt.show()

# %%
# 1. Bar plot for Average Scores by Performance
plt.figure(figsize=(10, 6))
df.groupby('Performance').mean().plot(kind='bar', stacked=False, colormap='viridis')
plt.title("Average Scores by Performance Grade")
plt.xlabel("Performance Grade")
plt.ylabel("Average Scores")
plt.show()

# %%
# 2. Line plot for Scores across Performance Groups
plt.figure(figsize=(10, 6))
for col in ['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)', 'Practical Score (25%)', 'Exam Score (50%)']:
    sns.lineplot(data=df, x='Performance', y=col, marker='o', label=col)
plt.title("Scores across Performance Groups")
plt.xlabel("Performance")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
# 5. Violin plot of each column by Performance
columns = ['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)', 'Practical Score (25%)', 'Exam Score (50%)']
for col in columns:
    plt.figure(figsize=(8, 5))
    sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
    plt.title(f"{col} Distribution by Performance")
    plt.xlabel("Performance")
    plt.ylabel(col)
    plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\2921433833.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\2921433833.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\2921433833.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\2921433833.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\2921433833.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')

# %%
# 8. Strip plot for each column vs Performance
for col in columns:
    plt.figure(figsize=(8, 5))
    sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
    plt.title(f"{col} vs Performance (Strip Plot)")
    plt.xlabel("Performance")
    plt.ylabel(col)
    plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# C:\Users\PC\AppData\Local\Temp\ipykernel_1948\1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')

# %%
# 3. Pair plot to show relationships between columns and Performance
sns.pairplot(df, hue='Performance', palette='coolwarm', markers=["o", "s", "D", "^"])
plt.suptitle("Pair Plot of Scores with Performance", y=1.02)
plt.show()
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# # Data Encoding

# %%
df.head(10)
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
# 5              85                         81                25
# 6              83                         77                22
# 7              85                         84                13
# 8              62                         65                15
# 9              88                         90                 9
#
#    Practical Score (25%)  Exam Score (50%) Performance
# 0                     17                33           B
# 1                     14                26           C
# 2                     11                35           B
# 3                      9                19           D
# 4                     17                19           D
# 5                     17                38           A
# 6                     23                14           C
# 7                     14                35           B
# 8                     16                16           D
# 9                     21                23           C

# %%
# ordinal encoding library
from sklearn.preprocessing import OrdinalEncoder

# %%
# order of grades for encoding
performance_order = ['F','E','D', 'C', 'B', 'A']

# Initialize the OrdinalEncoder with custom categories
oe=OrdinalEncoder(categories=[performance_order])

# %%
# Apply the encoding and replace the 'Performance' column
df['Performance'] = oe.fit_transform(df[['Performance']])

# %%
# Transformed dataframe
df.head()
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
#
#    Practical Score (25%)  Exam Score (50%)  Performance
# 0                     17                33          4.0
# 1                     14                26          3.0
# 2                     11                35          4.0
# 3                      9                19          2.0
# 4                     17                19          2.0

# %% [markdown]
# # Checking The Co-Relation Percentage Between Columns

# %%
plt.figure(figsize=(8,6))
plt.title("Heatmap for checking co-relation")
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: title={'center': 'Heatmap for checking co-relation'}>

# %% [markdown]
# # Train & Test Data Seperation

# %%
x=df.drop(columns=['Performance'])

# %%
y=df.Performance

# %%
x
# Out:
#       Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0                 95                         86                12
# 1                 78                         92                19
# 2                 97                         87                23
# 3                 74                         69                12
# 4                 62                         74                10
# ...              ...                        ...               ...
# 4995              83                         86                13
# 4996              88                         92                17
# 4997              93                         85                10
# 4998              97                         77                21
# 4999              91                         87                21
#
#       Practical Score (25%)  Exam Score (50%)
# 0                        17                33
# 1                        14                26
# 2                        11                35
# 3                         9                19
# 4                        17                19
# ...                     ...               ...
# 4995                      9                29
# 4996                     11                31
# 4997                     11                31
# 4998                     22                42
# 4999                     13                48
#
# [5000 rows x 5 columns]

# %%
y
# Out:
# 0       4.0
# 1       3.0
# 2       4.0
# 3       2.0
# 4       2.0
#        ...
# 4995    3.0
# 4996    3.0
# 4997    3.0
# 4998    5.0
# 4999    5.0
# Name: Performance, Length: 5000, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[ 1.12317517,  0.30173788, -0.85565543,  0.12163993,  0.29673103],
#        [-0.45013261,  0.85927277,  0.49086406, -0.45686323, -0.27171922],
#        [ 1.3082702 ,  0.39466036,  1.26030377, -1.03536639,  0.45914539],
#        ...,
#        [ 0.93808013,  0.2088154 , -1.24037528, -1.03536639,  0.13431667],
#        [ 1.3082702 , -0.53456445,  0.87558392,  1.08581187,  1.02759564],
#        [ 0.7529851 ,  0.39466036,  0.87558392, -0.64969762,  1.51483872]],
#       shape=(5000, 5))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[ 0.84553262,  0.2088154 ,  0.87558392, -0.07119446,  0.86518128],
#        [ 0.7529851 ,  1.32388517,  0.49086406,  0.31447432, -0.02809768],
#        [ 0.38279504, -0.44164197,  0.68322399, -0.26402884,  1.35242436],
#        ...,
#        [-0.54268013, -0.06995204, -0.6632955 ,  1.27864625,  0.21552385],
#        [-0.54268013,  0.95219525, -0.85565543,  0.89297748,  1.51483872],
#        [ 0.01260497, -0.06995204,  1.26030377, -0.64969762, -0.84016947]],
#       shape=(4000, 5))

# %%
x_test
# Out:
# array([[-0.54268013,  1.41680765, -1.43273521, -0.07119446,  0.29673103],
#        [-0.45013261,  0.39466036,  1.4526637 ,  0.5073087 , -0.59654794],
#        [-0.72777516,  0.39466036, -0.6632955 , -1.03536639,  0.0531095 ],
#        ...,
#        [ 0.1977    ,  1.13804021,  1.26030377, -0.842532  , -1.00258383],
#        [-0.26503758,  0.2088154 ,  1.26030377, -0.26402884,  1.67725307],
#        [-0.82032267, -0.81333189, -1.62509514, -1.42103516, -0.43413358]],
#       shape=(1000, 5))

# %%
y_train
# Out:
# 4227    5.0
# 4676    4.0
# 800     5.0
# 3671    3.0
# 4193    5.0
#        ...
# 4426    4.0
# 466     5.0
# 3092    4.0
# 3772    5.0
# 860     3.0
# Name: Performance, Length: 4000, dtype: float64

# %%
y_test
# Out:
# 1501    3.0
# 2586    4.0
# 2653    3.0
# 1055    3.0
# 705     3.0
#        ...
# 4711    5.0
# 2313    5.0
# 3214    3.0
# 2732    5.0
# 1926    2.0
# Name: Performance, Length: 1000, dtype: float64

# %% [markdown]
# # Modeling & Evaluation

# %% [markdown]
# ### Models List
#
# 1. RandomForest Classifier
# 2. Bagging Classifier
# 3. ExtraTrees Classifier
# 4. XGB Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
rfc = RandomForestClassifier(n_estimators=300, max_depth=10, max_features='sqrt', random_state=10)

base_clf = DecisionTreeClassifier(max_depth=20)  
bgc = BaggingClassifier(estimator=base_clf, n_estimators=300, max_samples=0.9, random_state=20)

etc = ExtraTreesClassifier(n_estimators=300, min_samples_split=5, max_depth=None, random_state=30)

xgc = XGBClassifier(n_estimators=300, learning_rate=0.1, max_depth=6, subsample=0.8, random_state=40)

# %%
classifiers={
    
    'RFC':rfc,
    'BGC':bgc,
    'ETC':etc,
    'XGB':xgc
    
}

# %%
# Define train_classifier function with confusion matrix display and additional metrics
def train_classifier(classifier, x_train, y_train, x_test, y_test, name):
    # Train the classifier
    classifier.fit(x_train, y_train)
    
    # Make predictions
    y_pred = classifier.predict(x_test)
    
    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    # Generate and display confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    
    plt.title(f"Confusion Matrix for {name}")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
    
    return accuracy, precision, recall, f1

# %%
# Lists to store accuracy, precision, recall, and F1 scores
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Loop through each classifier
for name, clf in classifiers.items():
    # Train the classifier, get metrics, and display confusion matrix
    current_accuracy, current_precision, current_recall, current_f1 = train_classifier(clf, x_train, y_train, x_test, y_test, name)
    
    # Print the classifier's performance metrics
    print(f'Name: {name}')
    print(f'Accuracy: {current_accuracy}')
    print(f'Precision: {current_precision}')
    print(f'Recall: {current_recall}')
    print(f'F1 Score: {current_f1}')
    print('----------------------------')
    
    # Append scores to the lists
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# Name: RFC
# Accuracy: 0.921
# Precision: 0.9223090073903113
# Recall: 0.921
# F1 Score: 0.9210906766752384
# ----------------------------
# Name: BGC
# Accuracy: 0.942
# Precision: 0.9428473256220071
# Recall: 0.942
# F1 Score: 0.9421345019604058
# ----------------------------
# Name: ETC
# Accuracy: 0.944
# Precision: 0.9451392563311736
# Recall: 0.944
# F1 Score: 0.9435387291410584
# ----------------------------
# Name: XGB
# Accuracy: 0.955
# Precision: 0.9556968018950058
# Recall: 0.955
# F1 Score: 0.95522941464626
# ----------------------------

# %%
performance_df=pd.DataFrame({'Algorithm':classifiers.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores,'Recall':recall_scores,'F1':f1_scores})
performance_df
# Out:
#   Algorithm  Accuracy  Precision  Recall        F1
# 0       RFC     0.921   0.922309   0.921  0.921091
# 1       BGC     0.942   0.942847   0.942  0.942135
# 2       ETC     0.944   0.945139   0.944  0.943539
# 3       XGB     0.955   0.955697   0.955  0.955229

# %%
performance_df1=pd.melt(performance_df,id_vars='Algorithm')
performance_df1
# Out:
#    Algorithm   variable     value
# 0        RFC   Accuracy  0.921000
# 1        BGC   Accuracy  0.942000
# 2        ETC   Accuracy  0.944000
# 3        XGB   Accuracy  0.955000
# 4        RFC  Precision  0.922309
# 5        BGC  Precision  0.942847
# 6        ETC  Precision  0.945139
# 7        XGB  Precision  0.955697
# 8        RFC     Recall  0.921000
# 9        BGC     Recall  0.942000
# 10       ETC     Recall  0.944000
# 11       XGB     Recall  0.955000
# 12       RFC         F1  0.921091
# 13       BGC         F1  0.942135
# 14       ETC         F1  0.943539
# 15       XGB         F1  0.955229

# %% [markdown]
# # Accuracy Graph For Each Algorithm

# %%
sns.catplot(x='Algorithm',y='value',hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0,1)
plt.xticks(rotation='vertical')
plt.show()
